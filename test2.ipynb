# %%
import pandas as pd

# %%
df = pd.read_csv('test.csv')

# %%
df.head()
# Out:
#                                            Job Title Min Salary Estimate  \
# 0  Data Analyst, Center on Immigration and Justic...            $37,000
# 1                               Quality Data Analyst            $37,000
# 2  Senior Data Analyst, Insights & Analytics Team...            $37,000
# 3                                       Data Analyst            $37,000
# 4                             Reporting Data Analyst            $37,000
#
#   Max Salary Estimate Avg Salary Estimate  Rating  \
# 0            $66,000             $51,500      3.2
# 1            $66,000             $51,500      3.8
# 2            $66,000             $51,500      3.4
# 3            $66,000             $51,500      4.1
# 4            $66,000             $51,500      3.9
#
#                                 Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\r\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\r\n3.8  New York, NY  New York, NY
# 2                         Squarespace\r\n3.4  New York, NY  New York, NY
# 3                            Celerity\r\n4.1  New York, NY    McLean, VA
# 4                             FanDuel\r\n3.9  New York, NY  New York, NY
#
#                      Size               Type of ownership  \
# 0    201 to 500 employees          Nonprofit Organization
# 1        10000+ employees          Nonprofit Organization
# 2  1001 to 5000 employees               Company - Private
# 3    201 to 500 employees  Subsidiary or Business Segment
# 4   501 to 1000 employees               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#    Latitude  Longitude
# 0  40.71427  -74.00597
# 1  40.71427  -74.00597
# 2  40.71427  -74.00597
# 3  40.71427  -74.00597
# 4  40.71427  -74.00597

# %%
data = df.to_dict('records')
data
# Out:
# [{'Job Title': 'Data Analyst, Center on Immigration and Justice (CIJ)',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 3.2,
#   'Company Name': 'Vera Institute of Justice\r\n3.2',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '201 to 500 employees',
#   'Type of ownership': 'Nonprofit Organization',
#   'Industry': 'Social Assistance',
#   'Sector': 'Non-Profit',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Quality Data Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 3.8,
#   'Company Name': 'Visiting Nurse Service of New York\r\n3.8',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Nonprofit Organization',
#   'Industry': 'Health Care Services & Hospitals',
#   'Sector': 'Health Care',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Senior Data Analyst, Insights & Analytics Team [Customer Operations]',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 3.4,
#   'Company Name': 'Squarespace\r\n3.4',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Internet',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 4.1,
#   'Company Name': 'Celerity\r\n4.1',
#   'Location': 'New York, NY',
#   'Headquarters': 'McLean, VA',
#   'Size': '201 to 500 employees',
#   'Type of ownership': 'Subsidiary or Business Segment',
#   'Industry': 'IT Services',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Reporting Data Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 3.9,
#   'Company Name': 'FanDuel\r\n3.9',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '501 to 1000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Sports & Recreation',
#   'Sector': 'Arts, Entertainment & Recreation',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 3.9,
#   'Company Name': 'Point72\r\n3.9',
#   'Location': 'New York, NY',
#   'Headquarters': 'Stamford, CT',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Investment Banking & Asset Management',
#   'Sector': 'Finance',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Business/Data Analyst (FP&A)',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 4.4,
#   'Company Name': 'Two Sigma\r\n4.4',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Investment Banking & Asset Management',
#   'Sector': 'Finance',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Science Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 3.7,
#   'Company Name': 'GNY Insurance Companies\r\n3.7',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '201 to 500 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Insurance Carriers',
#   'Sector': 'Insurance',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 4.0,
#   'Company Name': 'DMGT\r\n4.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'London, United Kingdom',
#   'Size': '5001 to 10000 employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Venture Capital & Private Equity',
#   'Sector': 'Finance',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst, Merchant Health',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 4.4,
#   'Company Name': 'Riskified\r\n4.4',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '501 to 1000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Research & Development',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 4.0,
#   'Company Name': 'NYU Langone Health\r\n4.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Hospital',
#   'Industry': 'Health Care Services & Hospitals',
#   'Sector': 'Health Care',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': -1.0,
#   'Company Name': 'BulbHead',
#   'Location': 'Fairfield, NJ',
#   'Headquarters': '-1',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.88255,
#   'Longitude': -74.30402},
#  {'Job Title': 'DATA ANALYST',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 3.7,
#   'Company Name': 'Montefiore Medical\r\n3.7',
#   'Location': 'New York, NY',
#   'Headquarters': 'Bronx, NY',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Nonprofit Organization',
#   'Industry': 'Health Care Services & Hospitals',
#   'Sector': 'Health Care',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Senior Data Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 3.0,
#   'Company Name': 'Known\r\n3.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '201 to 500 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Advertising & Marketing',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Investment Advisory Data Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 3.4,
#   'Company Name': 'Advisor Group\r\n3.4',
#   'Location': 'Jersey City, NJ',
#   'Headquarters': 'Phoenix, AZ',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Brokerage Services',
#   'Sector': 'Finance',
#   'Latitude': 40.728159999999995,
#   'Longitude': -74.07764},
#  {'Job Title': 'Sustainability Data Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 3.6,
#   'Company Name': 'CodeGreen Solutions\r\n3.6',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Building & Personnel Services',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 3.8,
#   'Company Name': 'Undertone\r\n3.8',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '201 to 500 employees',
#   'Type of ownership': 'Subsidiary or Business Segment',
#   'Industry': 'Advertising & Marketing',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Clinical Data Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 3.8,
#   'Company Name': 'NYSTEC\r\n3.8',
#   'Location': 'New York, NY',
#   'Headquarters': 'Rome, NY',
#   'Size': '51 to 200 employees',
#   'Type of ownership': 'Nonprofit Organization',
#   'Industry': 'Consulting',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'DATA PROGRAMMER/ANALYST',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 3.9,
#   'Company Name': 'Education Development Center, Inc.\r\n3.9',
#   'Location': 'New York, NY',
#   'Headquarters': 'Waltham, MA',
#   'Size': '501 to 1000 employees',
#   'Type of ownership': 'Nonprofit Organization',
#   'Industry': 'Research & Development',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 4.9,
#   'Company Name': 'Teachers Pay Teachers\r\n4.9',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '51 to 200 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Internet',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Product Analyst, Data Science',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 4.4,
#   'Company Name': 'Google\r\n4.4',
#   'Location': 'New York, NY',
#   'Headquarters': 'Mountain View, CA',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Internet',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Science Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': -1.0,
#   'Company Name': 'MUSIC & Entertainment',
#   'Location': 'New York, NY',
#   'Headquarters': 'Marina del Rey, CA',
#   'Size': 'Unknown',
#   'Type of ownership': 'Company - Public',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst - Intex Developer',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 3.3,
#   'Company Name': 'Macquarie Group\r\n3.3',
#   'Location': 'New York, NY',
#   'Headquarters': 'Sydney, Australia',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Investment Banking & Asset Management',
#   'Sector': 'Finance',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 3.5,
#   'Company Name': 'Andiamo\r\n3.5',
#   'Location': 'New York, NY',
#   'Headquarters': 'Warren, MI',
#   'Size': '201 to 500 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Casual Restaurants',
#   'Sector': 'Restaurants, Bars & Food Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Entry Level / Jr. Data Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 3.8,
#   'Company Name': 'Dash Technologies Inc\r\n3.8',
#   'Location': 'New York, NY',
#   'Headquarters': 'Columbus, OH',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Unknown',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 4.0,
#   'Company Name': 'Hearst Communications\r\n4.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'San Francisco, CA',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Advertising & Marketing',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data + Business Intelligence Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 5.0,
#   'Company Name': 'Duolingo\r\n5.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'Pittsburgh, PA',
#   'Size': '201 to 500 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Internet',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst, Product',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 4.8,
#   'Company Name': 'Ro\r\n4.8',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '51 to 200 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Health Care Services & Hospitals',
#   'Sector': 'Health Care',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst Entry Level',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 3.7,
#   'Company Name': 'Endai\r\n3.7',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Advertising & Marketing',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$37,000 ',
#   'Max Salary Estimate': '$66,000 ',
#   'Avg Salary Estimate': '$51,500 ',
#   'Rating': 4.7,
#   'Company Name': 'BlueLabs\r\n4.7',
#   'Location': 'New York, NY',
#   'Headquarters': 'Washington, DC',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Research & Development',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 3.6,
#   'Company Name': 'Revel\r\n3.6',
#   'Location': 'Brooklyn, NY',
#   'Headquarters': 'Seattle, WA',
#   'Size': '51 to 200 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Consulting',
#   'Sector': 'Business Services',
#   'Latitude': 40.6501,
#   'Longitude': -73.94958000000001},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 3.6,
#   'Company Name': 'NALLAS CORPORATION\r\n3.6',
#   'Location': 'Jersey City, NJ',
#   'Headquarters': 'Newtown, PA',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Enterprise Software & Network Solutions',
#   'Sector': 'Information Technology',
#   'Latitude': 40.728159999999995,
#   'Longitude': -74.07764},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 3.5,
#   'Company Name': 'Pozent\r\n3.5',
#   'Location': 'New York, NY',
#   'Headquarters': 'Piscataway, NJ',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Contract',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Science Analyst, Capital Markets',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 3.2,
#   'Company Name': 'SoFi\r\n3.2',
#   'Location': 'New York, NY',
#   'Headquarters': 'San Francisco, CA',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Lending',
#   'Sector': 'Finance',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst (Games)',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': -1.0,
#   'Company Name': 'Carry1st',
#   'Location': 'New York, NY',
#   'Headquarters': '-1',
#   'Size': '-1',
#   'Type of ownership': '-1',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Analyst/Associate Global Markets Credit Data Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 3.7,
#   'Company Name': 'Bank of America\r\n3.7',
#   'Location': 'New York, NY',
#   'Headquarters': 'Charlotte, NC',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Banks & Credit Unions',
#   'Sector': 'Finance',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Business Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': -1.0,
#   'Company Name': 'Clear Street',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '51 to 200 employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst with Excel/DAX/ PowerBI experience- Fulltime',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 3.6,
#   'Company Name': 'Nutech Information Systems\r\n3.6',
#   'Location': 'New York, NY',
#   'Headquarters': 'Westmont, IL',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Computer Hardware & Software',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Science Analyst/Engineer',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 4.0,
#   'Company Name': 'NYU Langone Health\r\n4.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Hospital',
#   'Industry': 'Health Care Services & Hospitals',
#   'Sector': 'Health Care',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 4.6,
#   'Company Name': 'The Trevor Project\r\n4.6',
#   'Location': 'New York, NY',
#   'Headquarters': 'West Hollywood, CA',
#   'Size': '51 to 200 employees',
#   'Type of ownership': 'Nonprofit Organization',
#   'Industry': 'Social Assistance',
#   'Sector': 'Non-Profit',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Business Analyst, Data Platforms',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': -1.0,
#   'Company Name': 'Pinto',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Behavioral Data Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': -1.0,
#   'Company Name': 'AB InBev',
#   'Location': 'New York, NY',
#   'Headquarters': 'Kyiv, Ukraine',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 5.0,
#   'Company Name': 'Whip Media Group\r\n5.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'Santa Monica, CA',
#   'Size': '51 to 200 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst -1+ year Contract - NYC',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 4.0,
#   'Company Name': 'Two95 International Inc.\r\n4.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'Cherry Hill, NJ',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Staffing & Outsourcing',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 3.0,
#   'Company Name': 'Vettery\r\n3.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '201 to 500 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Internet',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 2.9,
#   'Company Name': 'Nesco Resource, LLC\r\n2.9',
#   'Location': 'New York, NY',
#   'Headquarters': 'Cleveland, OH',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Staffing & Outsourcing',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Advertising Data Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 4.0,
#   'Company Name': 'Hearst Communications\r\n4.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'San Francisco, CA',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Advertising & Marketing',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 3.6,
#   'Company Name': 'MediaMath\r\n3.6',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '501 to 1000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Advertising & Marketing',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Market Data Reporting Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 4.9,
#   'Company Name': 'Jordan & Jordan\r\n4.9',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Brokerage Services',
#   'Sector': 'Finance',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Senior Analyst, Data Science',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 3.9,
#   'Company Name': 'Roku\r\n3.9',
#   'Location': 'New York, NY',
#   'Headquarters': 'San Jose, CA',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'IT Services',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Senior Data Analyst, Disney+',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 4.0,
#   'Company Name': 'Walt Disney Co.\r\n4.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'Burbank, CA',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Motion Picture Production & Distribution',
#   'Sector': 'Media',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Office of the CAO | Reference Data, Project Manager/Business Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 3.8,
#   'Company Name': 'Citadel\r\n3.8',
#   'Location': 'New York, NY',
#   'Headquarters': 'Chicago, IL',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Business Data Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 3.7,
#   'Company Name': 'Xoriant Corporation\r\n3.7',
#   'Location': 'Jersey City, NJ',
#   'Headquarters': 'Sunnyvale, CA',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'IT Services',
#   'Sector': 'Information Technology',
#   'Latitude': 40.728159999999995,
#   'Longitude': -74.07764},
#  {'Job Title': 'Senior Data Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 3.6,
#   'Company Name': 'Gemini\r\n3.6',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '51 to 200 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Brokerage Services',
#   'Sector': 'Finance',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Scientist / Big Data Analytics Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 3.6,
#   'Company Name': 'TSR, Inc.\r\n3.6',
#   'Location': 'Weehawken, NJ',
#   'Headquarters': 'Hauppauge, NY',
#   'Size': '201 to 500 employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Staffing & Outsourcing',
#   'Sector': 'Business Services',
#   'Latitude': 40.76955,
#   'Longitude': -74.02042},
#  {'Job Title': 'Data Reporting Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': -1.0,
#   'Company Name': 'NADAP NYS INC.',
#   'Location': 'New York, NY',
#   'Headquarters': '-1',
#   'Size': '-1',
#   'Type of ownership': '-1',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Principal Data Analyst, LATAM - Disney Streaming Services',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 4.0,
#   'Company Name': 'Walt Disney Co.\r\n4.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'Burbank, CA',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Motion Picture Production & Distribution',
#   'Sector': 'Media',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst II',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 3.2,
#   'Company Name': 'Fragomen Worldwide\r\n3.2',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Legal',
#   'Sector': 'Accounting & Legal',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst - Environmental, Social, and Governance',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 3.8,
#   'Company Name': 'Bloomberg\r\n3.8',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Computer Hardware & Software',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$66,500 ',
#   'Rating': 3.9,
#   'Company Name': 'Real Capital Analytics\r\n3.9',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '51 to 200 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Real Estate',
#   'Sector': 'Real Estate',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst, Revenue Analytics',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 4.8,
#   'Company Name': 'Ro\r\n4.8',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '51 to 200 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Health Care Services & Hospitals',
#   'Sector': 'Health Care',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst - Data Acquisition / Data Lineage',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 3.6,
#   'Company Name': 'Perficient\r\n3.6',
#   'Location': 'New York, NY',
#   'Headquarters': 'Saint Louis, MO',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'IT Services',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst - Data Scanning utilizing Rochade',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 3.6,
#   'Company Name': 'Perficient\r\n3.6',
#   'Location': 'New York, NY',
#   'Headquarters': 'Saint Louis, MO',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'IT Services',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst - Stitching',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 3.6,
#   'Company Name': 'Perficient\r\n3.6',
#   'Location': 'New York, NY',
#   'Headquarters': 'Saint Louis, MO',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'IT Services',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Junior Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 4.1,
#   'Company Name': 'Kforce\r\n4.1',
#   'Location': 'New York, NY',
#   'Headquarters': 'Tampa, FL',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Staffing & Outsourcing',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst, Retail Media',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 3.9,
#   'Company Name': 'Criteo\r\n3.9',
#   'Location': 'New York, NY',
#   'Headquarters': 'Paris, France',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Internet',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 3.0,
#   'Company Name': 'Royal Communications\r\n3.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'IT Services',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Portfolio Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 3.7,
#   'Company Name': 'Neuberger Berman\r\n3.7',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Investment Banking & Asset Management',
#   'Sector': 'Finance',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Science Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': -1.0,
#   'Company Name': 'Greater New York Mutual Insurance Companies (GNY)',
#   'Location': 'New York, NY',
#   'Headquarters': '-1',
#   'Size': '-1',
#   'Type of ownership': '-1',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data/Reporting Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 3.9,
#   'Company Name': 'Diverse Lynx\r\n3.9',
#   'Location': 'New York, NY',
#   'Headquarters': 'Princeton, NJ',
#   'Size': '501 to 1000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'IT Services',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst 2',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 3.7,
#   'Company Name': 'eTeam Inc.\r\n3.7',
#   'Location': 'New York, NY',
#   'Headquarters': 'South Plainfield, NJ',
#   'Size': '51 to 200 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Staffing & Outsourcing',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Entry Level Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': -1.0,
#   'Company Name': 'impakt Advisors',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Consulting',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Marketing Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 3.6,
#   'Company Name': 'Current\r\n3.6',
#   'Location': 'New York, NY',
#   'Headquarters': 'Colorado Springs, CO',
#   'Size': '201 to 500 employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data/Information Mgt Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 3.7,
#   'Company Name': 'Citi\r\n3.7',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Investment Banking & Asset Management',
#   'Sector': 'Finance',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Business Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 3.6,
#   'Company Name': 'Axelon Services Corporation\r\n3.6',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '501 to 1000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Staffing & Outsourcing',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Information Systems Officer (Data Analyst)',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 4.1,
#   'Company Name': 'United Nations\r\n4.1',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Government',
#   'Industry': 'Federal Agencies',
#   'Sector': 'Government',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Media Science Big Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 3.5,
#   'Company Name': 'Discovery Communications, Inc.\r\n3.5',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'TV Broadcast & Cable Networks',
#   'Sector': 'Media',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 3.7,
#   'Company Name': 'Randstad\r\n3.7',
#   'Location': 'Jersey City, NJ',
#   'Headquarters': 'Atlanta, GA',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Subsidiary or Business Segment',
#   'Industry': 'Staffing & Outsourcing',
#   'Sector': 'Business Services',
#   'Latitude': 40.728159999999995,
#   'Longitude': -74.07764},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 5.0,
#   'Company Name': 'Mulberry Technology\r\n5.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY (US), NY',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data analyst with Python',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 4.0,
#   'Company Name': 'Two95 International Inc.\r\n4.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'Cherry Hill, NJ',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Staffing & Outsourcing',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 4.8,
#   'Company Name': 'SoftStandard Solutions\r\n4.8',
#   'Location': 'New York, NY',
#   'Headquarters': 'Fremont, CA',
#   'Size': '51 to 200 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 5.0,
#   'Company Name': 'EDO, Inc.\r\n5.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'Los Angeles, CA',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Internet',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Healthcare Data Analyst, Qsight',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 3.3,
#   'Company Name': 'Guidepoint\r\n3.3',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '501 to 1000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Research & Development',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'BA/Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 4.1,
#   'Company Name': 'Mitchell Martin\r\n4.1',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '501 to 1000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Staffing & Outsourcing',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst Python',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 4.0,
#   'Company Name': 'Lorven Technologies Inc\r\n4.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'Plainsboro, NJ',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Accounting',
#   'Sector': 'Accounting & Legal',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst, Bitcoin Trading Firm',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': -1.0,
#   'Company Name': 'Fintech Recruiters',
#   'Location': 'New York, NY',
#   'Headquarters': 'Dublin, Ireland',
#   'Size': 'Unknown',
#   'Type of ownership': 'Company - Private',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst-BA',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 1.0,
#   'Company Name': 'Sphinix Network Solutions Inc.\r\n1.0',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'IT Services',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analytics Solutions Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 3.1,
#   'Company Name': 'Praescient Analytics\r\n3.1',
#   'Location': 'New York, NY',
#   'Headquarters': 'Alexandria, VA',
#   'Size': '51 to 200 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Consulting',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Quantitative Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 4.5,
#   'Company Name': 'Global Atlantic Financial Group\r\n4.5',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Insurance Carriers',
#   'Sector': 'Insurance',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$88,000 ',
#   'Avg Salary Estimate': '$69,500 ',
#   'Rating': 3.4,
#   'Company Name': 'FINRA\r\n3.4',
#   'Location': 'New York, NY',
#   'Headquarters': 'Washington, DC',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Nonprofit Organization',
#   'Industry': 'Brokerage Services',
#   'Sector': 'Finance',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$69,000 ',
#   'Rating': -1.0,
#   'Company Name': 'NYU Langone Medical Center',
#   'Location': 'New York, NY',
#   'Headquarters': '-1',
#   'Size': '-1',
#   'Type of ownership': '-1',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Descriptive Analytics Data Analyst, IB',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$69,000 ',
#   'Rating': 3.6,
#   'Company Name': 'Jefferies\r\n3.6',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Investment Banking & Asset Management',
#   'Sector': 'Finance',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$69,000 ',
#   'Rating': 4.1,
#   'Company Name': 'RGP\r\n4.1',
#   'Location': 'New York, NY',
#   'Headquarters': 'Irvine, CA',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Consulting',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$69,000 ',
#   'Rating': 4.4,
#   'Company Name': 'Tachyon Technologies\r\n4.4',
#   'Location': 'New York, NY',
#   'Headquarters': 'Irving, TX',
#   'Size': '201 to 500 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'IT Services',
#   'Sector': 'Information Technology',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$69,000 ',
#   'Rating': 3.8,
#   'Company Name': 'Apex Systems\r\n3.8',
#   'Location': 'Jersey City, NJ',
#   'Headquarters': 'Glen Allen, VA',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Subsidiary or Business Segment',
#   'Industry': 'Staffing & Outsourcing',
#   'Sector': 'Business Services',
#   'Latitude': 40.728159999999995,
#   'Longitude': -74.07764},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$69,000 ',
#   'Rating': 3.2,
#   'Company Name': 'Hagerty Consulting\r\n3.2',
#   'Location': 'New York, NY',
#   'Headquarters': 'Evanston, IL',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Consulting',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$69,000 ',
#   'Rating': -1.0,
#   'Company Name': 'Gainful Health',
#   'Location': 'New York, NY',
#   'Headquarters': 'San Mateo, CA',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Food & Beverage Stores',
#   'Sector': 'Retail',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Business Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$69,000 ',
#   'Rating': 3.8,
#   'Company Name': 'Cortex consultants LLC\r\n3.8',
#   'Location': 'New York, NY',
#   'Headquarters': 'North Brunswick, NJ',
#   'Size': '501 to 1000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Consulting',
#   'Sector': 'Business Services',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$69,000 ',
#   'Rating': 4.7,
#   'Company Name': 'Medly Pharmacy\r\n4.7',
#   'Location': 'Brooklyn, NY',
#   'Headquarters': 'Brooklyn, NY',
#   'Size': '201 to 500 employees',
#   'Type of ownership': 'Unknown',
#   'Industry': 'Health Care Services & Hospitals',
#   'Sector': 'Health Care',
#   'Latitude': 40.6501,
#   'Longitude': -73.94958000000001},
#  {'Job Title': 'Healthcare Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$69,000 ',
#   'Rating': 2.3,
#   'Company Name': 'Fair Health\r\n2.3',
#   'Location': 'New York, NY',
#   'Headquarters': 'New York, NY',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Nonprofit Organization',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 40.71427,
#   'Longitude': -74.00596999999999},
#  {'Job Title': 'Supply Chain Data Analyst',
#   'Min Salary Estimate': '$51,000 ',
#   'Max Salary Estimate': '$87,000 ',
#   'Avg Salary Estimate': '$69,000 ',
#   'Rating': 3.8,
#   'Company Name': 'Peloton Interactive\r\n3.8',
# ...
#   'Headquarters': 'Lake Jackson, TX',
#   'Size': '501 to 1000 employees',
#   'Type of ownership': 'Nonprofit Organization',
#   'Industry': 'Banks & Credit Unions',
#   'Sector': 'Finance',
#   'Latitude': 29.750009999999996,
#   'Longitude': -95.35404},
#  {'Job Title': 'Data Expert (Analyst/Modeler)',
#   'Min Salary Estimate': '$74,000 ',
#   'Max Salary Estimate': '$123,000 ',
#   'Avg Salary Estimate': '$98,500 ',
#   'Rating': 4.8,
#   'Company Name': 'InvenTech Info\r\n4.8',
#   'Location': 'Houston, TX',
#   'Headquarters': 'Bengaluru, India',
#   'Size': '201 to 500 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'IT Services',
#   'Sector': 'Information Technology',
#   'Latitude': 29.763279999999998,
#   'Longitude': -95.36327},
#  {'Job Title': '.Net Developer - Program Data Design Analyst',
#   'Min Salary Estimate': '$74,000 ',
#   'Max Salary Estimate': '$123,000 ',
#   'Avg Salary Estimate': '$98,500 ',
#   'Rating': 2.2,
#   'Company Name': 'Harris County Appraisal District\r\n2.2',
#   'Location': 'Houston, TX',
#   'Headquarters': 'Houston, TX',
#   'Size': '501 to 1000 employees',
#   'Type of ownership': 'Government',
#   'Industry': 'Municipal Governments',
#   'Sector': 'Government',
#   'Latitude': 29.763279999999998,
#   'Longitude': -95.36327},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 3.1,
#   'Company Name': 'MUFG\r\n3.1',
#   'Location': 'Tempe, AZ',
#   'Headquarters': 'Tokyo, Japan',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Banks & Credit Unions',
#   'Sector': 'Finance',
#   'Latitude': 33.414770000000004,
#   'Longitude': -111.90931},
#  {'Job Title': 'Senior Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 4.4,
#   'Company Name': 'Integrate\r\n4.4',
#   'Location': 'Phoenix, AZ',
#   'Headquarters': 'Phoenix, AZ',
#   'Size': '201 to 500 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Enterprise Software & Network Solutions',
#   'Sector': 'Information Technology',
#   'Latitude': 33.44838,
#   'Longitude': -112.07404},
#  {'Job Title': 'Data Warehouse Analyst II-ST',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 3.2,
#   'Company Name': 'Desert Financial Credit Union\r\n3.2',
#   'Location': 'Phoenix, AZ',
#   'Headquarters': 'Phoenix, AZ',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Banks & Credit Unions',
#   'Sector': 'Finance',
#   'Latitude': 33.44838,
#   'Longitude': -112.07404},
#  {'Job Title': 'SQL Developer/Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 3.7,
#   'Company Name': 'Corbins Electric\r\n3.7',
#   'Location': 'Phoenix, AZ',
#   'Headquarters': 'Phoenix, AZ',
#   'Size': '501 to 1000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Construction',
#   'Sector': 'Construction, Repair & Maintenance',
#   'Latitude': 33.44838,
#   'Longitude': -112.07404},
#  {'Job Title': 'Jr. Analyst Data/Reporting',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 3.5,
#   'Company Name': 'The Judge Group, Inc.\r\n3.5',
#   'Location': 'Phoenix, AZ',
#   'Headquarters': 'Wayne, PA',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Staffing & Outsourcing',
#   'Sector': 'Business Services',
#   'Latitude': 33.44838,
#   'Longitude': -112.07404},
#  {'Job Title': 'Senior Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 4.0,
#   'Company Name': 'Discount Tire\r\n4.0',
#   'Location': 'Scottsdale, AZ',
#   'Headquarters': 'Scottsdale, AZ',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Automotive Parts & Accessories Stores',
#   'Sector': 'Retail',
#   'Latitude': 33.509209999999996,
#   'Longitude': -111.89903000000001},
#  {'Job Title': 'Data Warehouse Analyst III',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 3.2,
#   'Company Name': 'Desert Financial Credit Union\r\n3.2',
#   'Location': 'Phoenix, AZ',
#   'Headquarters': 'Phoenix, AZ',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Banks & Credit Unions',
#   'Sector': 'Finance',
#   'Latitude': 33.44838,
#   'Longitude': -112.07404},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 3.5,
#   'Company Name': 'Robert Half\r\n3.5',
#   'Location': 'Phoenix, AZ',
#   'Headquarters': 'Menlo Park, CA',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Staffing & Outsourcing',
#   'Sector': 'Business Services',
#   'Latitude': 33.44838,
#   'Longitude': -112.07404},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 4.9,
#   'Company Name': 'TekCom Resources, Inc.\r\n4.9',
#   'Location': 'Phoenix, AZ',
#   'Headquarters': 'King of Prussia, PA',
#   'Size': '51 to 200 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Staffing & Outsourcing',
#   'Sector': 'Business Services',
#   'Latitude': 33.44838,
#   'Longitude': -112.07404},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 4.1,
#   'Company Name': 'Viasat\r\n4.1',
#   'Location': 'Phoenix, AZ',
#   'Headquarters': 'Carlsbad, CA',
#   'Size': '5001 to 10000 employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Telecommunications Services',
#   'Sector': 'Telecommunications',
#   'Latitude': 33.44838,
#   'Longitude': -112.07404},
#  {'Job Title': 'Business Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 4.6,
#   'Company Name': 'National Education Partners\r\n4.6',
#   'Location': 'Scottsdale, AZ',
#   'Headquarters': 'Scottsdale, AZ',
#   'Size': '201 to 500 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Colleges & Universities',
#   'Sector': 'Education',
#   'Latitude': 33.509209999999996,
#   'Longitude': -111.89903000000001},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 3.6,
#   'Company Name': 'Parker & Lynch\r\n3.6',
#   'Location': 'Phoenix, AZ',
#   'Headquarters': 'Jacksonville, FL',
#   'Size': '501 to 1000 employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Staffing & Outsourcing',
#   'Sector': 'Business Services',
#   'Latitude': 33.44838,
#   'Longitude': -112.07404},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 3.0,
#   'Company Name': 'The Accuro Group\r\n3.0',
#   'Location': 'Tempe, AZ',
#   'Headquarters': 'Raleigh, NC',
#   'Size': '201 to 500 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Staffing & Outsourcing',
#   'Sector': 'Business Services',
#   'Latitude': 33.414770000000004,
#   'Longitude': -111.90931},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 3.2,
#   'Company Name': 'Modis\r\n3.2',
#   'Location': 'Phoenix, AZ',
#   'Headquarters': 'Zurich, Switzerland',
#   'Size': '5001 to 10000 employees',
#   'Type of ownership': 'Subsidiary or Business Segment',
#   'Industry': 'Staffing & Outsourcing',
#   'Sector': 'Business Services',
#   'Latitude': 33.44838,
#   'Longitude': -112.07404},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 2.9,
#   'Company Name': 'Gatestone & Co. Inc\r\n2.9',
#   'Location': 'Phoenix, AZ',
#   'Headquarters': 'North York, Canada',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Staffing & Outsourcing',
#   'Sector': 'Business Services',
#   'Latitude': 33.44838,
#   'Longitude': -112.07404},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 3.9,
#   'Company Name': 'Diverse Lynx\r\n3.9',
#   'Location': 'Tempe, AZ',
#   'Headquarters': 'Princeton, NJ',
#   'Size': '501 to 1000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'IT Services',
#   'Sector': 'Information Technology',
#   'Latitude': 33.414770000000004,
#   'Longitude': -111.90931},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 3.6,
#   'Company Name': 'FAMILY INVOLVEMENT CENTER\r\n3.6',
#   'Location': 'Phoenix, AZ',
#   'Headquarters': 'Phoenix, AZ',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Nonprofit Organization',
#   'Industry': 'Social Assistance',
#   'Sector': 'Non-Profit',
#   'Latitude': 33.44838,
#   'Longitude': -112.07404},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 2.5,
#   'Company Name': 'Career Evolutions\r\n2.5',
#   'Location': 'Scottsdale, AZ',
#   'Headquarters': 'Scottsdale, AZ',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 33.509209999999996,
#   'Longitude': -111.89903000000001},
#  {'Job Title': 'Fall 2020 Supply Chain Data Analyst Intern',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 3.6,
#   'Company Name': 'ON Semiconductor\r\n3.6',
#   'Location': 'Phoenix, AZ',
#   'Headquarters': 'Phoenix, AZ',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Electrical & Electronic Manufacturing',
#   'Sector': 'Manufacturing',
#   'Latitude': 33.44838,
#   'Longitude': -112.07404},
#  {'Job Title': 'Data Experience Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 3.6,
#   'Company Name': 'Charles Schwab\r\n3.6',
#   'Location': 'Phoenix, AZ',
#   'Headquarters': 'San Francisco, CA',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Investment Banking & Asset Management',
#   'Sector': 'Finance',
#   'Latitude': 33.44838,
#   'Longitude': -112.07404},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 4.4,
#   'Company Name': 'Softcom Systems\r\n4.4',
#   'Location': 'Tempe, AZ',
#   'Headquarters': 'Princeton, NJ',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'IT Services',
#   'Sector': 'Information Technology',
#   'Latitude': 33.414770000000004,
#   'Longitude': -111.90931},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': -1.0,
#   'Company Name': 'Door Sales & Installations',
#   'Location': 'Tempe, AZ',
#   'Headquarters': '-1',
#   'Size': '-1',
#   'Type of ownership': '-1',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 33.414770000000004,
#   'Longitude': -111.90931},
#  {'Job Title': 'Data Analyst, Marketing',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 4.6,
#   'Company Name': 'National Education Partners\r\n4.6',
#   'Location': 'Scottsdale, AZ',
#   'Headquarters': 'Scottsdale, AZ',
#   'Size': '201 to 500 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': 'Colleges & Universities',
#   'Sector': 'Education',
#   'Latitude': 33.509209999999996,
#   'Longitude': -111.89903000000001},
#  {'Job Title': 'Data Control Business Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 3.1,
#   'Company Name': 'MUFG\r\n3.1',
#   'Location': 'Tempe, AZ',
#   'Headquarters': 'Tokyo, Japan',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Banks & Credit Unions',
#   'Sector': 'Finance',
#   'Latitude': 33.414770000000004,
#   'Longitude': -111.90931},
#  {'Job Title': 'Network Security System/Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 3.1,
#   'Company Name': 'MUFG\r\n3.1',
#   'Location': 'Tempe, AZ',
#   'Headquarters': 'Tokyo, Japan',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Banks & Credit Unions',
#   'Sector': 'Finance',
#   'Latitude': 33.414770000000004,
#   'Longitude': -111.90931},
#  {'Job Title': 'Data Center Services Analyst I, II, III, or Senior',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 3.4,
#   'Company Name': 'Alaska USA\r\n3.4',
#   'Location': 'Glendale, AZ',
#   'Headquarters': 'Anchorage, AK',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Other Organization',
#   'Industry': 'Banks & Credit Unions',
#   'Sector': 'Finance',
#   'Latitude': 33.53865,
#   'Longitude': -112.18598999999999},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 2.9,
#   'Company Name': 'The Paragon Group\r\n2.9',
#   'Location': 'Scottsdale, AZ',
#   'Headquarters': 'SUNDERLAND, United Kingdom',
#   'Size': '1001 to 5000 employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Banks & Credit Unions',
#   'Sector': 'Finance',
#   'Latitude': 33.509209999999996,
#   'Longitude': -111.89903000000001},
#  {'Job Title': 'Central Flow Data Analyst',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': 3.9,
#   'Company Name': 'Amazon\r\n3.9',
#   'Location': 'Tempe, AZ',
#   'Headquarters': 'Seattle, WA',
#   'Size': '10000+ employees',
#   'Type of ownership': 'Company - Public',
#   'Industry': 'Internet',
#   'Sector': 'Information Technology',
#   'Latitude': 33.414770000000004,
#   'Longitude': -111.90931},
#  {'Job Title': 'Data Center Services Analyst I, II, III, or Senior',
#   'Min Salary Estimate': '$53,000 ',
#   'Max Salary Estimate': '$94,000 ',
#   'Avg Salary Estimate': '$73,500 ',
#   'Rating': -1.0,
#   'Company Name': 'AlaskaUSA Mortgage Company',
#   'Location': 'Glendale, AZ',
#   'Headquarters': '-1',
#   'Size': '-1',
#   'Type of ownership': '-1',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 33.53865,
#   'Longitude': -112.18598999999999},
#  {'Job Title': 'Data Analyst - Data Science and Analytics',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$102,000 ',
#   'Avg Salary Estimate': '$74,000 ',
#   'Rating': -1.0,
#   'Company Name': 'MLWIZ Team',
#   'Location': 'Phoenix, AZ',
#   'Headquarters': 'North Brunswick, NJ',
#   'Size': '1 to 50 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 33.44838,
#   'Longitude': -112.07404},
#  {'Job Title': 'Data Analyst',
#   'Min Salary Estimate': '$46,000 ',
#   'Max Salary Estimate': '$102,000 ',
#   'Avg Salary Estimate': '$74,000 ',
#   'Rating': 4.3,
#   'Company Name': 'Net Orbit Inc\r\n4.3',
#   'Location': 'Tempe, AZ',
#   'Headquarters': 'Tempe, AZ',
#   'Size': '501 to 1000 employees',
#   'Type of ownership': 'Company - Private',
#   'Industry': '-1',
#   'Sector': '-1',
#   'Latitude': 33.414770000000004,
#   'Longitude': -111.90931},
#  ...]

# %%
import pymongo

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

db = client.Market_db
jobs = db.jobs

# %%
db.jobs.insert_many(data)
